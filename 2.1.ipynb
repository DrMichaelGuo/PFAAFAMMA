# %% [markdown]
# # 2.1 Variables

# %% [markdown]
# ## Key Concepts

# %%
sales = 2500

# %%
revenue = 150000
profit = 40000

# %%
this_is_snake_case = 10
cost_of_goods_sold = 5000

# %% [markdown]
# ## Follow-Along Activity

# %%
revenue = 150000
expenses = 85000
print(revenue)
print(expenses)
# Out:
# 150000
# 85000

# %%
revenue = 170000
print(revenue)
print(expenses)
# Out:
# 170000
# 85000

# %% [markdown]
# ## Your Project

# %%
assets = 200000
liabilities = 120000
print(assets)
print(liabilities)
# Out:
# 200000
# 120000

# %%
assets = 210000
print(assets)
print(liabilities)
# Out:
# 210000
# 120000
