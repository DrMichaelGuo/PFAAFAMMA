# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Welcome")
print("Welcome to Python for Accounting and Finance")
print("Welcome to Python for Accounting and Finance: a Mind Mapping Approach")
# Out:
# Welcome
# Welcome to Python for Accounting and Finance
# Welcome to Python for Accounting and Finance: a Mind Mapping Approach
