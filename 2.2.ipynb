# %% [markdown]
# # 2.2 Data Types

# %% [markdown]
# # Key Concepts

# %%
number_of_transactions = 125
number_of_employees = 42
accounting_period_months = 12

# %%
revenue = 152340.75
interest_rate = 0.045
vat_rate = 0.2

# %%
client_name = "ABC Consulting Ltd"
account_type = "Current Assets"
currency = 'GBP'

# %%
budget_exceeded = True
is_vat_registered = False
audit_required = True

# %% [markdown]
# ## Follow-Along Activity

# %%
revenue = 150000.75
transaction_count = 320
print("Revenue:", revenue)
print("Transaction Count:", transaction_count)
# Out:
# Revenue: 150000.75
# Transaction Count: 320

# %%
report_title = "Quarterly Financial Report"
print(report_title)
# Out:
# Quarterly Financial Report

# %%
is_target_reached = True
print("Target Reached:", is_target_reached)
# Out:
# Target Reached: True

# %% [markdown]
# ## Your Project

# %%
total_expenses = 85000.50
employee_count = 50
report_name = "Monthly Expense Report"
under_budget = True

print("Total Expenses:", total_expenses)
print("Employee Count:", employee_count)
print("Report Name:", report_name)
print("Under Budget:", under_budget)
# Out:
# Total Expenses: 85000.5
# Employee Count: 50
# Report Name: Monthly Expense Report
# Under Budget: True
