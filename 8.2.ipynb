# %% [markdown]
# # Follow-Along Activity

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Generate sample data for 3 departments
np.random.seed(42)
data1 = np.random.normal(50, 10, 100)
data2 = np.random.normal(60, 15, 100)
data3 = np.random.normal(55, 20, 100)
data = [data1, data2, data3]

# %%
# Create the violin plot
fig, ax = plt.subplots(figsize=(8, 6))
ax.violinplot(data, showmeans=True)
ax.set_title("Violin Plot of Monthly Revenue for 3 Departments")
ax.set_xlabel("Department")
ax.set_ylabel("Monthly Revenue (£'000s)")
ax.set_xticks([1, 2, 3])
ax.set_xticklabels(["Dept 1", "Dept 2", "Dept 3"])

# Save to jpeg for textbook publication
plt.savefig("violin_plot.jpeg", dpi=300)
plt.show()

# %% [markdown]
# # Your Project

# %%
import matplotlib.pyplot as plt
import numpy as np

# Task 1: Generate sample data for 5 departments (e.g., monthly revenue in thousands)
np.random.seed(42)
data1 = np.random.normal(50, 10, 100)
data2 = np.random.normal(60, 15, 100)
data3 = np.random.normal(55, 20, 100)

# Task 1 continued: Add two more departments
data4 = np.random.normal(45, 5, 100)
data5 = np.random.normal(65, 10, 100)

# Combine all department data into a list
data = [data1, data2, data3, data4, data5]

# Create the violin plot and change the plot size
fig, ax = plt.subplots(figsize=(10, 6))
ax.violinplot(data, showmeans=True)

# Task 2: Update title
ax.set_title("Violin Plot of Monthly Revenue by 5 Department")
ax.set_xlabel("Department")
ax.set_ylabel("Monthly Revenue (£'000s)")

# Update x-axis labels for 5 departments
ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xticklabels(["Dept 1", "Dept 2", "Dept 3", "Dept 4", "Dept 5"])

plt.show()
